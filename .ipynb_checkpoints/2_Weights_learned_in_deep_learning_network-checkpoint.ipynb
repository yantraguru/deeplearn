# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:85% !important; }</style>"))
# Out:
# <style>.container { width:85% !important; }</style>

# %%
import os
import numpy as np
import pandas as pd

from os import listdir
from io import BytesIO
import requests

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers,models,utils
from tensorflow.keras.layers import Dense,Flatten
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import models

from scipy import stats
from sklearn import preprocessing

from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc

import PIL
from PIL import Image

from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt

import seaborn as sns
sns.set_style("white")

# %%
if tf.test.gpu_device_name():
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
else:
    print("Please install GPU version of TF")
# Out:
# Please install GPU version of TF

# %%
DATA_DIR = 'data/caps and shoes/'

# %%
def convert_img_to_data(image):
    data = np.asarray(image)
    gs_image = image.convert(mode='L')
    gs_data = np.asarray(gs_image)
    gs_resized = gs_image.resize((112,112))
    gs_resized_data = np.asarray(gs_resized)
    reshaped_gs_data = gs_resized_data.reshape(112*112)
    return reshaped_gs_data

def convert_images_from_dir(dir_path):
    image_data = []
    
    for filename in listdir(dir_path):
        image = Image.open(dir_path +os.sep + filename)
        reshaped_gs_data = convert_img_to_data(image)
        image_data.append(reshaped_gs_data)
    
    return image_data

def load_from_dir(dir_path, labels):
    label_data = []
    image_data = []
    for label in labels:
        data_from_dir = convert_images_from_dir(dir_path + label)
        labels_for_data = [label for i in range(len(data_from_dir))]
        image_data += data_from_dir
        label_data += labels_for_data
    
    print('Found %d images belonging to %d classes' % (len(image_data),  len(labels)))
    return (np.array(image_data),np.array(label_data))

def load_img_data(data_dir):
    train_dir = DATA_DIR + 'train/'
    validation_dir = DATA_DIR + 'val/'
    test_dir = DATA_DIR + 'test/'
    
    if (os.path.isdir(train_dir) and os.path.isdir(validation_dir) and os.path.isdir(test_dir)) :
        labels = [subdirname.name for subdirname in os.scandir(train_dir) if subdirname.is_dir()] 
        
        train_data = load_from_dir(train_dir,labels)
        validation_data = load_from_dir(validation_dir,labels)
        test_data = load_from_dir(test_dir,labels)
        
    return train_data, validation_data, test_data     

def url_to_image(img_url):
    response = requests.get(img_url)
    img = Image.open(BytesIO(response.content))
    return img

def plot_images(ims, figsize=(24,12), rows=1, interp=False, titles=None):
    f = plt.figure(figsize=figsize)
    cols = len(ims)//rows if len(ims) % 2 == 0 else len(ims)//rows + 1
    for i in range(len(ims)):
        sp = f.add_subplot(rows, cols, i+1)
        sp.axis('Off')
        if titles is not None:
            sp.set_title(titles[i], fontsize=18)
        
        plt.imshow(ims[i].reshape(112,112), cmap="gray")

# %%
train_data, validation_data, test_data = load_img_data(DATA_DIR)
X_train, y_train = train_data
X_val, y_val = validation_data
X_test, y_test = test_data
# Out:
# Found 200 images belonging to 2 classes
# Found 100 images belonging to 2 classes
# Found 50 images belonging to 2 classes

# %%
print('X_train shape : %s' % str(X_train.shape))
print('y_train shape : %s' % str(y_train.shape))
print('X_val shape : %s' % str(X_val.shape))
print('y_val shape : %s' % str(y_val.shape))
print('X_test shape : %s' % str(X_test.shape))
print('y_test shape : %s' % str(y_test.shape))
# Out:
# X_train shape : (200, 12544)
# y_train shape : (200,)
# X_val shape : (100, 12544)
# y_val shape : (100,)
# X_test shape : (50, 12544)
# y_test shape : (50,)

# %%
X_train = X_train.astype('float32') / 255
X_val = X_val.astype('float32') / 255
X_test = X_test.astype('float32') / 255

# %%
le = preprocessing.LabelEncoder()
le.fit(y_train)
y_train = le.transform(y_train)
y_val = le.transform(y_val)
y_test = le.transform(y_test)
y_train = utils.to_categorical(y_train)
y_val = utils.to_categorical(y_val)
y_test = utils.to_categorical(y_test)

# %%
print('y_train shape : %s' % str(y_train.shape))
print('y_val shape : %s' % str(y_val.shape))
print('y_test shape : %s' % str(y_test.shape))
# Out:
# y_train shape : (200, 2)
# y_val shape : (100, 2)
# y_test shape : (50, 2)

# %%
def define_model_architecture():
    model = models.Sequential()
    model.add(Dense(32, activation='relu', input_shape=(12544,)))
    model.add(Dense(16, activation='relu'))
    model.add(Dense(2, activation='softmax'))
    
    model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
model = define_model_architecture()
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 32)                401440
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 34
# =================================================================
# Total params: 402,002
# Trainable params: 402,002
# Non-trainable params: 0
# _________________________________________________________________

# %%
# %time history = model.fit(X_train, y_train, validation_data = (X_val,y_val), epochs=125, batch_size=200, shuffle=True)
# Out:
# Train on 200 samples, validate on 100 samples
# Epoch 1/125
# 200/200 [==============================] - 0s 487us/sample - loss: 0.6856 - accuracy: 0.5450 - val_loss: 0.7900 - val_accuracy: 0.5000
# Epoch 2/125
# 200/200 [==============================] - 0s 54us/sample - loss: 0.7932 - accuracy: 0.5000 - val_loss: 0.7136 - val_accuracy: 0.4500
# Epoch 3/125
# 200/200 [==============================] - 0s 58us/sample - loss: 0.6984 - accuracy: 0.5300 - val_loss: 0.6728 - val_accuracy: 0.5800
# Epoch 4/125
# 200/200 [==============================] - 0s 46us/sample - loss: 0.6690 - accuracy: 0.6150 - val_loss: 0.6637 - val_accuracy: 0.6700
# Epoch 5/125
# 200/200 [==============================] - 0s 56us/sample - loss: 0.6584 - accuracy: 0.6750 - val_loss: 0.6633 - val_accuracy: 0.5600
# Epoch 6/125
# 200/200 [==============================] - 0s 51us/sample - loss: 0.6615 - accuracy: 0.5250 - val_loss: 0.6904 - val_accuracy: 0.5200
# Epoch 7/125
# 200/200 [==============================] - 0s 47us/sample - loss: 0.6817 - accuracy: 0.5400 - val_loss: 0.6503 - val_accuracy: 0.6300
# Epoch 8/125
# 200/200 [==============================] - 0s 50us/sample - loss: 0.6400 - accuracy: 0.6200 - val_loss: 0.6319 - val_accuracy: 0.6600
# Epoch 9/125
# 200/200 [==============================] - 0s 46us/sample - loss: 0.6226 - accuracy: 0.6950 - val_loss: 0.6159 - val_accuracy: 0.6600
# Epoch 10/125
# 200/200 [==============================] - 0s 40us/sample - loss: 0.6098 - accuracy: 0.6300 - val_loss: 0.6928 - val_accuracy: 0.5500
# Epoch 11/125
# 200/200 [==============================] - 0s 47us/sample - loss: 0.6834 - accuracy: 0.5650 - val_loss: 0.6933 - val_accuracy: 0.5500
# Epoch 12/125
# 200/200 [==============================] - 0s 46us/sample - loss: 0.7004 - accuracy: 0.5100 - val_loss: 0.7905 - val_accuracy: 0.5000
# Epoch 13/125
# 200/200 [==============================] - 0s 40us/sample - loss: 0.7909 - accuracy: 0.5000 - val_loss: 0.7033 - val_accuracy: 0.5000
# Epoch 14/125
# 200/200 [==============================] - 0s 48us/sample - loss: 0.7033 - accuracy: 0.5000 - val_loss: 0.6885 - val_accuracy: 0.5000
# Epoch 15/125
# 200/200 [==============================] - 0s 49us/sample - loss: 0.6862 - accuracy: 0.5050 - val_loss: 0.6753 - val_accuracy: 0.5200
# Epoch 16/125
# 200/200 [==============================] - 0s 46us/sample - loss: 0.6727 - accuracy: 0.5600 - val_loss: 0.6582 - val_accuracy: 0.6500
# Epoch 17/125
# 200/200 [==============================] - 0s 49us/sample - loss: 0.6549 - accuracy: 0.6750 - val_loss: 0.6456 - val_accuracy: 0.7300
# Epoch 18/125
# 200/200 [==============================] - 0s 45us/sample - loss: 0.6375 - accuracy: 0.7550 - val_loss: 0.6350 - val_accuracy: 0.7000
# Epoch 19/125
# 200/200 [==============================] - 0s 40us/sample - loss: 0.6255 - accuracy: 0.7150 - val_loss: 0.6307 - val_accuracy: 0.7400
# Epoch 20/125
# 200/200 [==============================] - 0s 38us/sample - loss: 0.6204 - accuracy: 0.7350 - val_loss: 0.6270 - val_accuracy: 0.7100
# Epoch 21/125
# 200/200 [==============================] - 0s 34us/sample - loss: 0.6158 - accuracy: 0.7150 - val_loss: 0.6227 - val_accuracy: 0.7300
# Epoch 22/125
# 200/200 [==============================] - 0s 42us/sample - loss: 0.6117 - accuracy: 0.7400 - val_loss: 0.6202 - val_accuracy: 0.7200
# Epoch 23/125
# 200/200 [==============================] - 0s 40us/sample - loss: 0.6083 - accuracy: 0.7200 - val_loss: 0.6190 - val_accuracy: 0.7200
# Epoch 24/125
# 200/200 [==============================] - 0s 46us/sample - loss: 0.6078 - accuracy: 0.7400 - val_loss: 0.6191 - val_accuracy: 0.6900
# Epoch 25/125
# 200/200 [==============================] - 0s 46us/sample - loss: 0.6084 - accuracy: 0.7050 - val_loss: 0.6312 - val_accuracy: 0.6700
# Epoch 26/125
# 200/200 [==============================] - 0s 42us/sample - loss: 0.6179 - accuracy: 0.7050 - val_loss: 0.6338 - val_accuracy: 0.5900
# Epoch 27/125
# 200/200 [==============================] - 0s 45us/sample - loss: 0
125
# 200/200 [==============================] - 0s 47us/sample - loss: 0.5055 - accuracy: 0.7700 - val_loss: 0.5302 - val_accuracy: 0.7300
# Epoch 111/125
# 200/200 [==============================] - 0s 41us/sample - loss: 0.5005 - accuracy: 0.7400 - val_loss: 0.5568 - val_accuracy: 0.7400
# Epoch 112/125
# 200/200 [==============================] - 0s 44us/sample - loss: 0.5072 - accuracy: 0.7650 - val_loss: 0.5476 - val_accuracy: 0.7100
# Epoch 113/125
# 200/200 [==============================] - 0s 45us/sample - loss: 0.5169 - accuracy: 0.7400 - val_loss: 0.5885 - val_accuracy: 0.7300
# Epoch 114/125
# 200/200 [==============================] - 0s 46us/sample - loss: 0.5362 - accuracy: 0.7500 - val_loss: 0.5644 - val_accuracy: 0.6900
# Epoch 115/125
# 200/200 [==============================] - 0s 44us/sample - loss: 0.5338 - accuracy: 0.7550 - val_loss: 0.6001 - val_accuracy: 0.7200
# Epoch 116/125
# 200/200 [==============================] - 0s 47us/sample - loss: 0.5485 - accuracy: 0.7500 - val_loss: 0.5591 - val_accuracy: 0.6900
# Epoch 117/125
# 200/200 [==============================] - 0s 38us/sample - loss: 0.5297 - accuracy: 0.7600 - val_loss: 0.6076 - val_accuracy: 0.7400
# Epoch 118/125
# 200/200 [==============================] - 0s 47us/sample - loss: 0.5532 - accuracy: 0.7500 - val_loss: 0.5744 - val_accuracy: 0.7000
# Epoch 119/125
# 200/200 [==============================] - 0s 39us/sample - loss: 0.5411 - accuracy: 0.7500 - val_loss: 0.5627 - val_accuracy: 0.7500
# Epoch 120/125
# 200/200 [==============================] - 0s 45us/sample - loss: 0.5120 - accuracy: 0.7650 - val_loss: 0.5145 - val_accuracy: 0.7400
# Epoch 121/125
# 200/200 [==============================] - 0s 36us/sample - loss: 0.4839 - accuracy: 0.7500 - val_loss: 0.5267 - val_accuracy: 0.7600
# Epoch 122/125
# 200/200 [==============================] - 0s 42us/sample - loss: 0.4841 - accuracy: 0.7850 - val_loss: 0.5264 - val_accuracy: 0.7200
# Epoch 123/125
# 200/200 [==============================] - 0s 42us/sample - loss: 0.4899 - accuracy: 0.7650 - val_loss: 0.5387 - val_accuracy: 0.7300
# Epoch 124/125
# 200/200 [==============================] - 0s 45us/sample - loss: 0.4860 - accuracy: 0.7800 - val_loss: 0.5146 - val_accuracy: 0.7200
# Epoch 125/125
# 200/200 [==============================] - 0s 45us/sample - loss: 0.4779 - accuracy: 0.7500 - val_loss: 0.5532 - val_accuracy: 0.7500
# CPU times: user 3.43 s, sys: 128 ms, total: 3.56 s
# Wall time: 1.58 s

# %%
plt.figure(num=None, figsize=(16, 6))
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.legend()
plt.xlim(0, 500)
plt.show()

# %%
plt.figure(num=None, figsize=(16, 6))
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='validation')
plt.legend()
plt.xlim(0, 500)
plt.show()

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test, batch_size=50) 
print('Test loss: %.4f accuracy: %.4f' % (test_loss, test_accuracy))
# Out:
# 50/50 [==============================] - 0s 30us/sample - loss: 0.4714 - accuracy: 0.7800
# Test loss: 0.4714 accuracy: 0.7800

# %%
layers_info = {}
for i in model.layers:
    layers_info[i.name] = i.get_config()

layer_weights = {}
for i in model.layers:
    layer_weights[i.name] = i.get_weights()

# %%
layers_info['dense_3']
# Out:
# {'name': 'dense_3',
#  'trainable': True,
#  'batch_input_shape': (None, 12544),
#  'dtype': 'float32',
#  'units': 32,
#  'activation': 'relu',
#  'use_bias': True,
#  'kernel_initializer': {'class_name': 'GlorotUniform',
#   'config': {'seed': None}},
#  'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#  'kernel_regularizer': None,
#  'bias_regularizer': None,
#  'activity_regularizer': None,
#  'kernel_constraint': None,
#  'bias_constraint': None}

# %%
layers = model.layers
layer_ids = [1,4,7,11,15]
#plot the filters
fig,ax = plt.subplots(nrows=1,ncols=5)
for i in range(5):
    ax[i].imshow(layers[layer_ids[i]].get_weights()[0][:,:,:,0][:,:,0],cmap='gray')
    ax[i].set_title('block'+str(i+1))
    ax[i].set_xticks([])
    ax[i].set_yticks([])

# %%
for cnt,layer in enumerate(model.layers):
    print('Layer : %d'%cnt)
    print('Layer weight shape : %s' % str(layer.get_weights()[0].shape))
    print('Layer bias shape : %s' % str(layer.get_weights()[1].shape))
# Out:
# Layer : 0
# Layer weight shape : (12544, 32)
# Layer bias shape : (32,)
# Layer : 1
# Layer weight shape : (32, 16)
# Layer bias shape : (16,)
# Layer : 2
# Layer weight shape : (16, 2)
# Layer bias shape : (2,)

# %%
plt.imshow(model.layers[0].get_weights()[0][:32],cmap='gray')

# %%
plt.imshow(model.layers[1].get_weights()[0],cmap='gray')

# %%
layer_0_weights = model.layers[0].get_weights()[0].flatten()
layer_1_weights = model.layers[1].get_weights()[0].flatten()
layer_2_weights = model.layers[2].get_weights()[0].flatten()

# %%
kwargs = dict(hist_kws={'alpha':.6}, kde_kws={'linewidth':2})

plt.figure(figsize=(10,7), dpi= 80)
sns.distplot(layer_0_weights, color="dodgerblue", label="Layer 0", **kwargs)
sns.distplot(layer_1_weights, color="orange", label="Layer 1", **kwargs)
sns.distplot(layer_2_weights, color="deeppink", label="Layer 2", **kwargs)
plt.legend();

# %%
layer_0_bias = model.layers[0].get_weights()[1].flatten()
layer_1_bias = model.layers[1].get_weights()[1].flatten()
layer_2_bias = model.layers[2].get_weights()[1].flatten()

# %%
kwargs = dict(hist_kws={'alpha':.6}, kde_kws={'linewidth':2})

plt.figure(figsize=(10,7), dpi= 80)
sns.distplot(layer_0_bias, color="dodgerblue", label="Layer 0", **kwargs)
#sns.distplot(layer_1_bias, color="orange", label="Layer 1", **kwargs)
#sns.distplot(layer_2_bias, color="deeppink", label="Layer 2", **kwargs)
plt.legend();

# %%
example_ix = 22
image_2d_array = X_train[example_ix].reshape(112,112)
imshow(image_2d_array,cmap="gray")

# %%
layer_outputs = [layer.output for layer in model.layers]
activation_model = models.Model(inputs=model.input, outputs=layer_outputs)
activations = activation_model.predict(X_train[example_ix].reshape(1,112*112))

# %%
first_layer_activation = activations[0]
print(first_layer_activation.shape)
imshow(first_layer_activation, cmap='gray')
# Out:
# (1, 32)

# %%
first_layer_activation_img = np.pad(first_layer_activation[0], (2, 2), 'constant').reshape(6,6)
imshow(first_layer_activation_img,cmap="gray")

# %%
second_layer_activation = activations[1]
print(second_layer_activation.shape)
imshow(second_layer_activation, cmap='gray')
# Out:
# (1, 16)

# %%
second_layer_activation_img = second_layer_activation[0].reshape(4,4)
imshow(second_layer_activation_img,cmap="gray")

# %%
third_layer_activation = activations[2]
print(third_layer_activation.shape)
print(third_layer_activation)
imshow(third_layer_activation, cmap='gray')
# Out:
# (1, 2)
# [[0.8398634  0.16013661]]

# %%
example_ix = 123
image_2d_array = X_train[example_ix].reshape(112,112)

layer_outputs = [layer.output for layer in model.layers]
activation_model = models.Model(inputs=model.input, outputs=layer_outputs)
activations = activation_model.predict(X_train[example_ix].reshape(1,112*112))

first_layer_activation_img = np.pad(activations[0][0], (2, 2), 'constant').reshape(6,6)
second_layer_activation_img = activations[1][0].reshape(4,4)
third_layer_activation = activations[2]

ims = [image_2d_array,first_layer_activation_img,second_layer_activation_img,third_layer_activation]
titles = ['original image', 'first layer', 'second layer', third_layer_activation]

f = plt.figure(figsize=(24,12))
rows = 1
cols = 4

for i in range(len(ims)):
    sp = f.add_subplot(rows, cols, i+1)
    sp.axis('Off')
    sp.set_title(titles[i], fontsize=18)
    plt.imshow(ims[i], cmap="gray")
    
print('~'*120)
print(third_layer_activation)
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [[0.25569707 0.7443029 ]]
